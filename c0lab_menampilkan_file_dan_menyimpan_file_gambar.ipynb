# %% [markdown]
# <a href="https://colab.research.google.com/github/reyhanreyyy/UAS-PRAKTIKUM-KOMGRAF/blob/main/c0lab_menampilkan_file_dan_menyimpan_file_gambar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drives/')
# Out:
# Mounted at /content/drives/

# %%
import cv2
from google.colab.patches import cv2_imshow
img=cv2.imread('/cb.jpg', cv2.IMREAD_UNCHANGED)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=521x639 at 0x7F7FA8D26920>

# %%
print(img.shape)
# Out:
# (639, 521, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
img=cv2.imread('/cb.jpg', cv2.IMREAD_GRAYSCALE)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=521x639 at 0x7F7F6C363940>

# %%
print(img.shape)
# Out:
# (639, 521)

# %%
cv2.imwrite('/cb.jpg',img)
# Out:
# True
